# %% [markdown]
# <a href="https://colab.research.google.com/github/Gilles2711/Extended_learning_portfolio/blob/main/Question%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in Data (elp_sales.csv)
dataset = pd.read_csv("elp_sales.csv")
print(dataset)
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
dataset.columns
dataset.loc[dataset['Region']== "Australia and Oceania"]
# Out:
#                    Region                         Country        Item Type  \
# 0   Australia and Oceania                          Tuvalu        Baby Food
# 5   Australia and Oceania                 Solomon Islands        Baby Food
# 19  Australia and Oceania                      East Timor             Meat
# 23  Australia and Oceania                     New Zealand           Fruits
# 26  Australia and Oceania                        Kiribati           Fruits
# 32  Australia and Oceania                       Australia  Office Supplies
# 56  Australia and Oceania                            Fiji          Clothes
# 60  Australia and Oceania                       Australia           Cereal
# 76  Australia and Oceania  Federated States of Micronesia        Beverages
# 79  Australia and Oceania                          Samoa         Cosmetics
# 91  Australia and Oceania                       Australia        Beverages
#
# ...

# %%
#groupby - multiple group as columns
dataset.groupby(['Region', 'Country'], as_index=False)['Total Profit'].sum("Australia and Oceania")
g = dataset.groupby('Region')
g

# %%
# %matplotlib inline
g.plot()
# Out:
# Region
# Asia                                 AxesSubplot(0.125,0.125;0.775x0.755)
# Australia and Oceania                AxesSubplot(0.125,0.125;0.775x0.755)
# Central America and the Caribbean    AxesSubplot(0.125,0.125;0.775x0.755)
# Europe                               AxesSubplot(0.125,0.125;0.775x0.755)
# Middle East and North Africa         AxesSubplot(0.125,0.125;0.775x0.755)
# North America                        AxesSubplot(0.125,0.125;0.775x0.755)
# Sub-Saharan Africa                   AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
